# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = sns.load_dataset("penguins")

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.jointplot(data=df, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
average_body_mass = df.groupby("sex")["body_mass_g"].mean()

print(average_body_mass)
# Out:
# sex
# Female    3862.272727
# Male      4545.684524
# Name: body_mass_g, dtype: float64

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.groupby("species")[["bill_length_mm", "bill_depth_mm"]].mean()
# Out:
#            bill_length_mm  bill_depth_mm
# species
# Adelie          38.791391      18.346358
# Chinstrap       48.833824      18.420588
# Gentoo          47.504878      14.982114

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# # Homework

# %%
sns.relplot(data=df, kind="line", x="body_mass_g", y="flipper_length_mm")
sns.lmplot(data=df, x="body_mass_g", y="flipper_length_mm")

# %%
sns.lmplot(data=df, x="body_mass_g", y="flipper_length_mm", col="sex", hue="sex")

# %%
df.groupby("sex")[["flipper_length_mm", "body_mass_g"]].mean()
# Out:
#         flipper_length_mm  body_mass_g
# sex
# Female         197.363636  3862.272727
# Male           204.505952  4545.684524

# %%
r = df["flipper_length_mm"].corr(df["body_mass_g"])
print(f"Correlation Coefficient =  { r }")
# Out:
# Correlation Coefficient =  0.8712017673060111

# %%
df.groupby("island")[["flipper_length_mm", "body_mass_g"]].mean()
# Out:
#            flipper_length_mm  body_mass_g
# island
# Biscoe            209.706587  4716.017964
# Dream             193.072581  3712.903226
# Torgersen         191.196078  3706.372549

# %% [markdown]
# **Conclusion**
# 1. Penguin's body mass depends on flipper length, no anticorellation
# 2. Male penguins are hevier and have longer flipper, than females
# 3. We can guess, that conditions are much better on the Biscoe, this follows from the high size of the local penguins

# %% [markdown]
# **Comments**:
# 1. Not depends but correlates. Large rats are eaten by large cats but rat size does not depend on cat size, it's just a correlation
# 2. True
# 3. No, Biscoe is the only island where large Gentoo penguins dwell

# %% [markdown]
# Let's compute cross column frequences:

# %%
pd.crosstab(df["island"], df["species"], normalize="index")
# Out:
# species      Adelie  Chinstrap    Gentoo
# island
# Biscoe     0.261905   0.000000  0.738095
# Dream      0.451613   0.548387  0.000000
# Torgersen  1.000000   0.000000  0.000000

# %% [markdown]
# Let's visualize body mass distribution per species:

# %%
sns.boxplot(data=df, x="species", y="body_mass_g", hue="sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# Biscoe population is 26% of Adelie and 74% of large Gentoo, Gentoo penguins dwell only on Biscoe
